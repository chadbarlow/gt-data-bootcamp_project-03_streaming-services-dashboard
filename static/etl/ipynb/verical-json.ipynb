# %%
# Import dependencies.
import pandas as pd
import json

# %%
vertical_csv = '../csv/complete_data/complete_vertical.csv'

# %%
vertical_data = pd.read_csv(vertical_csv)

# %%
vertical_data.head(150)
# Out:
#      ID                                     title  score  \
# 0     1                              The Irishman     98
# 1     2                                    Dangal     97
# 2     2                                    Dangal     97
# 3     2                                    Dangal     97
# 4     3  David Attenborough: A Life on Our Planet     95
# ..   ..                                       ...    ...
# 145  70                       There Will Be Blood     84
# 146  70                       There Will Be Blood     84
# 147  71                       Million Dollar Baby     84
# 148  71                       Million Dollar Baby     84
# 149  72                        The Social Network     84
#
#                                               director  \
# 0                                      Martin Scorsese
# 1                                        Nitesh Tiwari
# 2                                        Nitesh Tiwari
# ...

# %%
vertical_data.to_json('../json/complete_vertical.json', orient='index')
